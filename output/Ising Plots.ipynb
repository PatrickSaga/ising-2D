# %%
# %matplotlib inline
import csv
from __future__ import division
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt

# L = 16
T_16,magnetization_16, magnetization2_16, susceptibility_16, err_mag_16 = [], [], [], [], []
with open('magnetization16', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_16.append(float(row[0]))
        magnetization_16.append(float(row[1]))
        magnetization2_16.append(float(row[2]))
        susceptibility_16.append(16*16*float(row[3]))
        err_mag_16.append(float(row[0])*float(row[3]))
T_16,energy_16, energy2_16, specific_heat_16, err_ene_16 = [], [], [], [], []
with open('energy16', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_16.append(float(row[0]))
        energy_16.append(float(row[1]))
        energy2_16.append(float(row[2]))
        specific_heat_16.append(16*16*float(row[3]))
        err_ene_16.append(float(row[3])*float(row[0])**2)
# L = 32
T_32,magnetization_32, magnetization2_32, susceptibility_32, err_mag_32 = [], [], [], [], []
with open('magnetization32', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_32.append(float(row[0]))
        magnetization_32.append(float(row[1]))
        magnetization2_32.append(float(row[2]))
        susceptibility_32.append(32*32*float(row[3]))
        err_mag_32.append(float(row[0])*float(row[3]))
T_32,energy_32, energy2_32, specific_heat_32, err_ene_32 = [], [], [], [], []
with open('energy32', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_32.append(float(row[0]))
        energy_32.append(float(row[1]))
        energy2_32.append(float(row[2]))
        specific_heat_32.append(32*32*float(row[3]))
        err_ene_32.append(float(row[3])*float(row[0])**2)
# L = 64
T_64,magnetization_64, magnetization2_64, susceptibility_64, err_mag_64 = [], [], [], [], []
with open('magnetization64', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_64.append(float(row[0]))
        magnetization_64.append(float(row[1]))
        magnetization2_64.append(float(row[2]))
        susceptibility_64.append(64*64*float(row[3]))
        err_mag_64.append(float(row[0])*float(row[3]))
T_64,energy_64, energy2_64, specific_heat_64, err_ene_64 = [], [], [], [], []
with open('energy64', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_64.append(float(row[0]))
        energy_64.append(float(row[1]))
        energy2_64.append(float(row[2]))
        specific_heat_64.append(64*64*float(row[3]))
        err_ene_64.append(float(row[3])*float(row[0])**2)
# L = 128
T_128,magnetization_128, magnetization2_128, susceptibility_128, err_mag_128 = [], [], [], [], []
with open('magnetization128', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_128.append(float(row[0]))
        magnetization_128.append(float(row[1]))
        magnetization2_128.append(float(row[2]))
        susceptibility_128.append(128*128*float(row[3]))
        err_mag_128.append(float(row[0])*float(row[3]))
T_128,energy_128, energy2_128, specific_heat_128, err_ene_128 = [], [], [], [], []
with open('energy128', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_128.append(float(row[0]))
        energy_128.append(float(row[1]))
        energy2_128.append(float(row[2]))
        specific_heat_128.append(128*128*float(row[3]))
        err_ene_128.append(float(row[3])*float(row[0])**2)

# plot the energy and Magnetization
f = plt.figure(figsize=(18, 10), dpi=80, facecolor='w', edgecolor='k');    

sp =  f.add_subplot(2, 2, 1 );
plt.plot(T_16, energy_16, '.', color="#A60628", label=' Energy');
plt.plot(T_32, energy_32, '.', label=' Energy');
plt.plot(T_64, energy_64, '.', label=' Energy');
#plt.plot(T_128, energy_128, '.', label=' Energy');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Energy ", fontsize=20);

sp =  f.add_subplot(2, 2, 2 );
plt.errorbar(T_16, magnetization_16, yerr=err_mag_16, color="#348ABD", label='Magnetization', fmt='*');
plt.errorbar(T_32, magnetization_32, yerr=err_mag_32, label='Magnetization', fmt='*');
#plt.errorbar(T_128, magnetization_128, yerr=err_mag_128, label='Magnetization', fmt='*');
plt.errorbar(T_64, magnetization_64, yerr=err_mag_64, label='Magnetization', fmt='*');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Magnetization ", fontsize=20);


sp =  f.add_subplot(2, 2, 3 );
plt.plot(T_16, specific_heat_16, 'd', color="black", label='Specific Heat');
plt.plot(T_32, specific_heat_32, 'd', label='Specific Heat');
plt.plot(T_64, specific_heat_64, 'd', label='Specific Heat');
#plt.plot(T_128, specific_heat_128, 'd', label='Specific Heat');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Specific Heat ", fontsize=20);


sp =  f.add_subplot(2, 2, 4 );
plt.plot(T_16, susceptibility_16, '+', color="green", label='Susceptibility');
plt.plot(T_32, susceptibility_32, '+', label='Susceptibility');
plt.plot(T_64, susceptibility_64, '+', label='Susceptibility');
#plt.plot(T_128, susceptibility_128, '+', label='Susceptibility');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Susceptibility", fontsize=20);
plt.xlim(2,3)
plt.show()

# %%
# %matplotlib inline
import csv
from __future__ import division
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt

# L = 16
T_16,magnetization_16, magnetization2_16, susceptibility_16, err_mag_16 = [], [], [], [], []
with open('magnetization', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_16.append(float(row[0]))
        magnetization_16.append(float(row[1]))
        magnetization2_16.append(float(row[2]))
        susceptibility_16.append(16*16*float(row[3]))
        err_mag_16.append(float(row[0])*float(row[3]))
T_16,energy_16, energy2_16, specific_heat_16, err_ene_16 = [], [], [], [], []
with open('energy', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_16.append(float(row[0]))
        energy_16.append(float(row[1]))
        energy2_16.append(float(row[2]))
        specific_heat_16.append(16*16*float(row[3]))
        err_ene_16.append(float(row[3])*float(row[0])**2)

# plot the energy and Magnetization
f = plt.figure(figsize=(18, 10), dpi=80, facecolor='w', edgecolor='k');    

sp =  f.add_subplot(2, 2, 1 );
plt.plot(T_16, energy_16, '.', color="#A60628", label=' Energy');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Energy ", fontsize=20);

sp =  f.add_subplot(2, 2, 2 );
plt.errorbar(T_16, magnetization_16, yerr=err_mag_16, color="#348ABD", label='Magnetization', fmt='*');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Magnetization ", fontsize=20);


sp =  f.add_subplot(2, 2, 3 );
plt.plot(T_16, specific_heat_16, 'd', color="black", label='Specific Heat');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Specific Heat ", fontsize=20);


sp =  f.add_subplot(2, 2, 4 );
plt.plot(T_16, susceptibility_16, '+', color="green", label='Susceptibility');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Susceptibility", fontsize=20);
plt.show()

# %%
# %matplotlib inline
import csv
from __future__ import division
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt
import math

M = 5000

# L = 16
T_16,magnetization_16, magnetization2_16, susceptibility_16, err_mag_16, err_susc_16 = [], [], [], [], [], []
with open('magnetization', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_16.append(float(row[0]))
        magnetization_16.append(float(row[1]))
        magnetization2_16.append(float(row[2]))
        susceptibility_16.append(float(row[3]))
        #susceptibility_16.append(32*32*float(row[3]))
        err_mag_16.append(math.sqrt(float(row[3]))/math.sqrt(M))
        err_susc_16.append(math.sqrt(float(row[4])-float(row[2])**2)/(float(row[0])*math.sqrt(M)))
        
T_16,energy_16, energy2_16, specific_heat_16, err_ene_16, err_sh_16 = [], [], [], [], [], []
with open('energy', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_16.append(float(row[0]))
        energy_16.append(float(row[1]))
        energy2_16.append(float(row[2]))
        specific_heat_16.append(float(row[3]))
        err_ene_16.append(math.sqrt(float(row[3]))/math.sqrt(M))
        #err_cap_16.append(math.sqrt(abs(float(row[4])-32*float(row[2])**2))/(float(row[0])**2))
        err_sh_16.append(math.sqrt(abs(float(row[4])-float(row[2])**2))/(float(row[0])**2*math.sqrt(M)))
        
# plot the energy and Magnetization
f = plt.figure(figsize=(18, 10), dpi=80, facecolor='w', edgecolor='k');    

sp =  f.add_subplot(2, 2, 1 );
plt.plot(T_16, energy_16, '.', color="#A60628", label=' Energy');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Energy ", fontsize=20);


sp =  f.add_subplot(2, 2, 2 );
plt.errorbar(T_16, magnetization_16, yerr=err_mag_16, color="#348ABD", label='Magnetization', fmt='*');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Magnetization ", fontsize=20);


sp =  f.add_subplot(2, 2, 3 );
#plt.plot(T_16, specific_heat_16, '.', color="black", label='Specific Heat');
plt.errorbar(T_16, specific_heat_16, yerr = err_cap_16, color="black", label='Specific Heat');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Specific Heat ", fontsize=20);
plt.xlim(2,3)
#plt.ylim(0,5)


sp =  f.add_subplot(2, 2, 4 );
plt.errorbar(T_16, susceptibility_16, yerr = err_susc_16, fmt='.', color="green", label='Susceptibility');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Susceptibility", fontsize=20);
plt.show()

# %%
# %matplotlib inline
import csv
from __future__ import division
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt
import math

M = 5000

# L = 16
T_16,magnetization_16, susceptibility_16, err_mag_16, err_susc_16 = [], [], [], [], []
with open('magnetization', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_16.append(float(row[0]))
        magnetization_16.append(float(row[1]))
        susceptibility_16.append(float(row[2]))
        err_mag_16.append(math.sqrt(float(row[2]))/math.sqrt(M))
        err_susc_16.append(float(row[3]))
        
T_16,energy_16, specific_heat_16, err_ene_16, err_sh_16 = [], [], [], [], []
with open('energy', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_16.append(float(row[0]))
        energy_16.append(float(row[1]))
        specific_heat_16.append(float(row[2]))
        err_ene_16.append(math.sqrt(float(row[2]))/math.sqrt(M))
        err_sh_16.append(float(row[3]))
        
# plot the energy and Magnetization
f = plt.figure(figsize=(18, 10), dpi=80, facecolor='w', edgecolor='k');    

sp =  f.add_subplot(2, 2, 1 );
plt.plot(T_16, energy_16, '.', color="#A60628", label=' Energy');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Energy ", fontsize=20);


sp =  f.add_subplot(2, 2, 2 );
plt.errorbar(T_16, magnetization_16, yerr=err_mag_16, color="#348ABD", label='Magnetization', fmt='*');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Magnetization ", fontsize=20);


sp =  f.add_subplot(2, 2, 3 );
#plt.plot(T_16, specific_heat_16, '.', color="black", label='Specific Heat');
plt.errorbar(T_16, specific_heat_16, yerr = err_sh_16, fmt = '.', color="black", label='Specific Heat');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Specific Heat ", fontsize=20);
plt.xlim(1.5,3)
plt.ylim(0,0.01)


sp =  f.add_subplot(2, 2, 4 );
plt.errorbar(T_16, susceptibility_16, yerr = err_susc_16, fmt='.', color="green", label='Susceptibility');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Susceptibility", fontsize=20);
plt.show()

# %%
# %matplotlib inline
import csv
from __future__ import division
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt
import math

M = 5000

# L = 8
T_8,magnetization_8, susceptibility_8, err_mag_8, err_susc_8 = [], [], [], [], []
with open('magnetization8', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_8.append(float(row[0]))
        magnetization_8.append(float(row[1]))
        susceptibility_8.append(float(row[2]))
        err_mag_8.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_8.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_8,energy_8, specific_heat_8, err_ene_8, err_sh_8 = [], [], [], [], []
with open('energy8', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_8.append(float(row[0]))
        energy_8.append(float(row[1]))
        specific_heat_8.append(float(row[2]))
        err_ene_8.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_8.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 16
T_16,magnetization_16, susceptibility_16, err_mag_16, err_susc_16 = [], [], [], [], []
with open('magnetization16', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_16.append(float(row[0]))
        magnetization_16.append(float(row[1]))
        susceptibility_16.append(float(row[2]))
        err_mag_16.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_16.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_16,energy_16, specific_heat_16, err_ene_16, err_sh_16 = [], [], [], [], []
with open('energy16', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_16.append(float(row[0]))
        energy_16.append(float(row[1]))
        specific_heat_16.append(float(row[2]))
        err_ene_16.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_16.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 32
T_32,magnetization_32, susceptibility_32, err_mag_32, err_susc_32 = [], [], [], [], []
with open('magnetization32', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_32.append(float(row[0]))
        magnetization_32.append(float(row[1]))
        susceptibility_32.append(float(row[2]))
        err_mag_32.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_32.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_32,energy_32, specific_heat_32, err_ene_32, err_sh_32 = [], [], [], [], []
with open('energy32', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_32.append(float(row[0]))
        energy_32.append(float(row[1]))
        specific_heat_32.append(float(row[2]))
        err_ene_32.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_32.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 64
T_64,magnetization_64, susceptibility_64, err_mag_64, err_susc_64 = [], [], [], [], []
with open('magnetization64', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_64.append(float(row[0]))
        magnetization_64.append(float(row[1]))
        susceptibility_64.append(float(row[2]))
        err_mag_64.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_64.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_64,energy_64, specific_heat_64, err_ene_64, err_sh_64 = [], [], [], [], []
with open('energy64', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_64.append(float(row[0]))
        energy_64.append(float(row[1]))
        specific_heat_64.append(float(row[2]))
        err_ene_64.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_64.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 128
T_128,magnetization_128, susceptibility_128, err_mag_128, err_susc_128 = [], [], [], [], []
with open('magnetization128', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_128.append(float(row[0]))
        magnetization_128.append(float(row[1]))
        susceptibility_128.append(float(row[2]))
        err_mag_128.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_128.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_128,energy_128, specific_heat_128, err_ene_128, err_sh_128 = [], [], [], [], []
with open('energy128', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_128.append(float(row[0]))
        energy_128.append(float(row[1]))
        specific_heat_128.append(float(row[2]))
        err_ene_128.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_128.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
        
# plot the energy and Magnetization
f = plt.figure(figsize=(18, 10), dpi=80, facecolor='w', edgecolor='k');    

sp =  f.add_subplot(2, 2, 1 );
plt.plot(T_8, energy_8, '.', color="#A60628", label=' L=8');
plt.plot(T_16, energy_16, '.', label='L=16');
plt.plot(T_32, energy_32, '.', label='L=32');
plt.plot(T_64, energy_64, '.', label='L=64');
plt.plot(T_128, energy_128, '.', label='L=128');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Energy ", fontsize=20);
plt.legend()

sp =  f.add_subplot(2, 2, 2 );
plt.errorbar(T_8, magnetization_8, yerr=err_mag_8, color="#348ABD", label='L=8', fmt='.');
plt.errorbar(T_16, magnetization_16, yerr=err_mag_16, label='L=16', fmt='.');
plt.errorbar(T_32, magnetization_32, yerr=err_mag_32, label='L=32', fmt='.');
plt.errorbar(T_64, magnetization_64, yerr=err_mag_64, label='L=64', fmt='.');
plt.errorbar(T_128, magnetization_128, yerr=err_mag_128, label='L=128', fmt='.');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Magnetization ", fontsize=20);
plt.legend()

sp =  f.add_subplot(2, 2, 3 );
#plt.errorbar(T_16, specific_heat_16, yerr = err_sh_16, fmt = '.', color="black", label='Specific Heat');
plt.plot(T_8, specific_heat_8, '.', color="black", label='L=8');
plt.plot(T_16, specific_heat_16, '.', label='L=16');
plt.plot(T_32, specific_heat_32, '.', label='L=32');
plt.plot(T_64, specific_heat_64, '.', label='L=64');
plt.plot(T_128, specific_heat_128, '.', label='L=128');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Specific Heat ", fontsize=20);
plt.xlim(2,3)
plt.legend()

sp =  f.add_subplot(2, 2, 4 );
plt.errorbar(T_8, susceptibility_8, yerr = err_susc_8, fmt='.', color="green", label='L=8');
plt.errorbar(T_16, susceptibility_16, yerr = err_susc_16, fmt='.', label='L=16');
plt.errorbar(T_32, susceptibility_32, yerr = err_susc_32, fmt='.', label='L=32');
plt.errorbar(T_64, susceptibility_64, yerr = err_susc_64, fmt='.', label='L=64');
plt.errorbar(T_128, susceptibility_128, yerr = err_susc_128, fmt='.', label='L=128');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Susceptibility", fontsize=20);
plt.xlim(2.2,2.5)
plt.legend()
plt.show()

# %%
# %matplotlib inline
import csv
from __future__ import division
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt
import math

M = 5000

# L = 8
T_8,magnetization_8, susceptibility_8, err_mag_8, err_susc_8 = [], [], [], [], []
with open('magnetization8', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_8.append(float(row[0]))
        magnetization_8.append(float(row[1]))
        susceptibility_8.append(8**2*float(row[2]))
        err_mag_8.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_8.append(8**2*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_8,energy_8, specific_heat_8, err_ene_8, err_sh_8 = [], [], [], [], []
with open('energy8', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_8.append(float(row[0]))
        energy_8.append(float(row[1]))
        specific_heat_8.append(8**2*float(row[2]))
        err_ene_8.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_8.append(8**2*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 16
T_16,magnetization_16, susceptibility_16, err_mag_16, err_susc_16 = [], [], [], [], []
with open('magnetization16', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_16.append(float(row[0]))
        magnetization_16.append(float(row[1]))
        susceptibility_16.append(16**2*float(row[2]))
        err_mag_16.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_16.append(16**2*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_16,energy_16, specific_heat_16, err_ene_16, err_sh_16 = [], [], [], [], []
with open('energy16', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_16.append(float(row[0]))
        energy_16.append(float(row[1]))
        specific_heat_16.append(16**2*float(row[2]))
        err_ene_16.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_16.append(16**2*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 32
T_32,magnetization_32, susceptibility_32, err_mag_32, err_susc_32 = [], [], [], [], []
with open('magnetization32', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_32.append(float(row[0]))
        magnetization_32.append(float(row[1]))
        susceptibility_32.append(32**2*float(row[2]))
        err_mag_32.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_32.append(32**2*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_32,energy_32, specific_heat_32, err_ene_32, err_sh_32 = [], [], [], [], []
with open('energy32', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_32.append(float(row[0]))
        energy_32.append(float(row[1]))
        specific_heat_32.append(32**2*float(row[2]))
        err_ene_32.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_32.append(32**2*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 64
T_64,magnetization_64, susceptibility_64, err_mag_64, err_susc_64 = [], [], [], [], []
with open('magnetization64', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_64.append(float(row[0]))
        magnetization_64.append(float(row[1]))
        susceptibility_64.append(64**2*float(row[2]))
        err_mag_64.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_64.append(64**2*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_64,energy_64, specific_heat_64, err_ene_64, err_sh_64 = [], [], [], [], []
with open('energy64', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_64.append(float(row[0]))
        energy_64.append(float(row[1]))
        specific_heat_64.append(64**2*float(row[2]))
        err_ene_64.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_64.append(64**2*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 128
T_128,magnetization_128, susceptibility_128, err_mag_128, err_susc_128 = [], [], [], [], []
with open('magnetization128', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_128.append(float(row[0]))
        magnetization_128.append(float(row[1]))
        susceptibility_128.append(128**2*float(row[2]))
        err_mag_128.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_128.append(128**2*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_128,energy_128, specific_heat_128, err_ene_128, err_sh_128 = [], [], [], [], []
with open('energy128', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_128.append(float(row[0]))
        energy_128.append(float(row[1]))
        specific_heat_128.append(128**2*float(row[2]))
        err_ene_128.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_128.append(128**2*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
        
# plot the energy and Magnetization
f = plt.figure(figsize=(18, 10), dpi=80, facecolor='w', edgecolor='k');    

sp =  f.add_subplot(2, 2, 2 );
plt.errorbar(T_8, energy_8,yerr= err_ene_8, fmt='.', label=' L=8');
plt.errorbar(T_16, energy_16,yerr= err_ene_16, fmt='.', label='L=16');
plt.errorbar(T_32, energy_32,yerr= err_ene_32,fmt='.', label='L=32');
plt.errorbar(T_64, energy_64,yerr= err_ene_64, fmt='.', label='L=64');
plt.errorbar(T_128, energy_128,yerr= err_ene_128, fmt='.', label='L=128');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Energy ", fontsize=20);
plt.legend()

sp =  f.add_subplot(2, 2, 1 );
plt.errorbar(T_8, magnetization_8, yerr=err_mag_8, label='L=8', fmt='.');
plt.errorbar(T_16, magnetization_16, yerr=err_mag_16, label='L=16', fmt='.');
plt.errorbar(T_32, magnetization_32, yerr=err_mag_32, label='L=32', fmt='.');
plt.errorbar(T_64, magnetization_64, yerr=err_mag_64, label='L=64', fmt='.');
plt.errorbar(T_128, magnetization_128, yerr=err_mag_128, label='L=128', fmt='.');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Magnetization ", fontsize=20);
plt.legend()

sp =  f.add_subplot(2, 2, 4 );
#plt.errorbar(T_16, specific_heat_16, yerr = err_sh_16, fmt = '.', color="black", label='Specific Heat');
plt.plot(T_8, specific_heat_8, '.-', label='L=8');
plt.plot(T_16, specific_heat_16, '.-', label='L=16');
plt.plot(T_32, specific_heat_32, '.-', label='L=32');
plt.plot(T_64, specific_heat_64, '.-', label='L=64');
plt.plot(T_128, specific_heat_128, '.-', label='L=128');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Specific Heat ", fontsize=20);
plt.xlim(2,2.6)
plt.legend()

sp =  f.add_subplot(2, 2, 3 );
plt.errorbar(T_8, susceptibility_8, yerr = err_susc_8, fmt='.', label='L=8');
plt.errorbar(T_16, susceptibility_16, yerr = err_susc_16, fmt='.', label='L=16');
plt.errorbar(T_32, susceptibility_32, yerr = err_susc_32, fmt='.', label='L=32');
plt.errorbar(T_64, susceptibility_64, yerr = err_susc_64, fmt='.', label='L=64');
plt.errorbar(T_128, susceptibility_128, yerr = err_susc_128, fmt='.', label='L=128');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Susceptibility", fontsize=20);
plt.xlim(2.2,2.5)
plt.legend()
plt.savefig('ising.pdf')
plt.show()

# %%
# %matplotlib inline
import csv
from __future__ import division
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt
import math

M = 5000

# L = 8
T_8,magnetization_8, susceptibility_8, err_mag_8, err_susc_8 = [], [], [], [], []
with open('magnetization8', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_8.append(float(row[0]))
        magnetization_8.append(float(row[1]))
        susceptibility_8.append(8*8*float(row[2]))
        err_mag_8.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_8.append(8*8*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_8,energy_8, specific_heat_8, err_ene_8, err_sh_8 = [], [], [], [], []
with open('energy8', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_8.append(float(row[0]))
        energy_8.append(float(row[1]))
        specific_heat_8.append(8*8*float(row[2]))
        err_ene_8.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_8.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 16
T_16,magnetization_16, susceptibility_16, err_mag_16, err_susc_16 = [], [], [], [], []
with open('magnetization16', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_16.append(float(row[0]))
        magnetization_16.append(float(row[1]))
        susceptibility_16.append(16*16*float(row[2]))
        err_mag_16.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_16.append(16*16*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_16,energy_16, specific_heat_16, err_ene_16, err_sh_16 = [], [], [], [], []
with open('energy16', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_16.append(float(row[0]))
        energy_16.append(float(row[1]))
        specific_heat_16.append(16*16*float(row[2]))
        err_ene_16.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_16.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 32
T_32,magnetization_32, susceptibility_32, err_mag_32, err_susc_32 = [], [], [], [], []
with open('magnetization32', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_32.append(float(row[0]))
        magnetization_32.append(float(row[1]))
        susceptibility_32.append(32*32*float(row[2]))
        err_mag_32.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_32.append(32*32*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_32,energy_32, specific_heat_32, err_ene_32, err_sh_32 = [], [], [], [], []
with open('energy32', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_32.append(float(row[0]))
        energy_32.append(float(row[1]))
        specific_heat_32.append(32*32*float(row[2]))
        err_ene_32.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_32.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 64
T_64,magnetization_64, susceptibility_64, err_mag_64, err_susc_64 = [], [], [], [], []
with open('magnetization64', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_64.append(float(row[0]))
        magnetization_64.append(float(row[1]))
        susceptibility_64.append(64*64*float(row[2]))
        err_mag_64.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_64.append(64*64*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_64,energy_64, specific_heat_64, err_ene_64, err_sh_64 = [], [], [], [], []
with open('energy64', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_64.append(float(row[0]))
        energy_64.append(float(row[1]))
        specific_heat_64.append(64*64*float(row[2]))
        err_ene_64.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_64.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 128
T_128,magnetization_128, susceptibility_128, err_mag_128, err_susc_128 = [], [], [], [], []
with open('magnetization128', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_128.append(float(row[0]))
        magnetization_128.append(float(row[1]))
        susceptibility_128.append(128*128*float(row[2]))
        err_mag_128.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_128.append(128*128*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_128,energy_128, specific_heat_128, err_ene_128, err_sh_128 = [], [], [], [], []
with open('energy128', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_128.append(float(row[0]))
        energy_128.append(float(row[1]))
        specific_heat_128.append(128*128*float(row[2]))
        err_ene_128.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_128.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
        
# plot the energy and Magnetization
f = plt.figure(figsize=(18, 10), dpi=80, facecolor='w', edgecolor='k');    

plt.errorbar(T_8, energy_8,yerr= err_ene_8, fmt='.', label=' L=8');
plt.errorbar(T_16, energy_16,yerr= err_ene_16, fmt='.', label='L=16');
plt.errorbar(T_32, energy_32,yerr= err_ene_32,fmt='.', label='L=32');
plt.errorbar(T_64, energy_64,yerr= err_ene_64, fmt='.', label='L=64');
plt.errorbar(T_128, energy_128,yerr= err_ene_128, fmt='.', label='L=128');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Energy", fontsize=20);
plt.legend(loc = 'upper left')
#plt.savefig('energy.pdf')
plt.show()


plt.errorbar(T_8, magnetization_8, yerr=err_mag_8, label='L=8', fmt='.');
plt.errorbar(T_16, magnetization_16, yerr=err_mag_16, label='L=16', fmt='.');
plt.errorbar(T_32, magnetization_32, yerr=err_mag_32, label='L=32', fmt='.');
plt.errorbar(T_64, magnetization_64, yerr=err_mag_64, label='L=64', fmt='.');
plt.errorbar(T_128, magnetization_128, yerr=err_mag_128, label='L=128', fmt='.');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Magnetization", fontsize=20);
plt.legend()
#plt.savefig('magnetization.pdf')
plt.show()


#plt.errorbar(T_16, specific_heat_16, yerr = err_sh_16, fmt = '.', color="black", label='Specific Heat');
plt.plot(T_8, specific_heat_8, '.', label='L=8');
plt.plot(T_16, specific_heat_16, '.', label='L=16');
plt.plot(T_32, specific_heat_32, '.', label='L=32');
plt.plot(T_64, specific_heat_64,'.', label='L=64');
plt.plot(T_128, specific_heat_128, '.', label='L=128');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Specific Heat", fontsize=20);
plt.xlim(2,2.6)
plt.legend()
#plt.savefig('heatN.pdf')
plt.show()


plt.errorbar(T_8, susceptibility_8, yerr = err_susc_8, fmt='.', label='L=8');
plt.errorbar(T_16, susceptibility_16, yerr = err_susc_16, fmt='.', label='L=16');
plt.errorbar(T_32, susceptibility_32, yerr = err_susc_32, fmt='.', label='L=32');
plt.errorbar(T_64, susceptibility_64, yerr = err_susc_64, fmt='.', label='L=64');
plt.errorbar(T_128, susceptibility_128, yerr = err_susc_128, fmt='.', label='L=128');
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Susceptibility", fontsize=20);
plt.xlim(2.2,2.5)
plt.legend()
#plt.savefig('susceptibilityN.pdf')
plt.show()

# %%
# %matplotlib inline
import csv
from __future__ import division
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt
import math
from pylab import * 

Tc = [2.64, 2.38, 2.3, 2.28, 2.26]
N = [1/(8*8), 1/(16*16), 1/(32*32), 1/(64*64), 1/(128*128)]
m,b = polyfit(N, Tc, 1) 

plt.errorbar(N, Tc, yerr= 0.03, fmt='o');
#plt.plot(N, Tc, N, m*N+b, '--k')
plt.xlabel("$1/N$", fontsize=20);
plt.ylabel("$T_c$", fontsize=20);
plt.legend(loc = 'upper left')
plt.savefig('linearfit.pdf')
plt.show()

# %%
# %matplotlib inline
import csv
from __future__ import division
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt
import math
from pylab import * 

corr, d = [],[]
with open('correlation238', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    for row in reader:
        corr.append(float(row[0]))
        d.append(float(row[1]))
        
plt.plot(d, corr, label = 'T=2.38');
plt.xlabel("$r$", fontsize=20);
plt.ylabel("$Corr(r)$", fontsize=20);
plt.legend(loc = 'upper right')
plt.savefig('corr.pdf')
plt.show()
      
xi = [1.008622433,0.988607096,0.97177361,0.939227142]
t=[0.048920229, 0.053327457,0.057734685, 0.079770824]
plt.plot(t, xi, 'o');
plt.ylabel("$log(corr.length)$", fontsize=20);
plt.xlabel("$t$", fontsize=20);
plt.savefig('corrlength.pdf')
plt.show()

# %%
# %matplotlib inline
import csv
from __future__ import division
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt
import math

M = 5000

# L = 8
T_8,magnetization_8, susceptibility_8, err_mag_8, err_susc_8 = [], [], [], [], []
with open('magnetization8', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_8.append(8*(float(row[0])-2.269)/2.269)
        magnetization_8.append(8*8*8**(-0.125)*float(row[1]))
        susceptibility_8.append(8*8*8**(-1.75)*float(row[2]))
        err_mag_8.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_8.append(8*8*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_8,energy_8, specific_heat_8, err_ene_8, err_sh_8 = [], [], [], [], []
with open('energy8', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_8.append(8*(float(row[0])-2.269)/2.269)
        energy_8.append(float(row[1]))
        specific_heat_8.append(8*8*float(row[2]))
        err_ene_8.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_8.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 16
T_16,magnetization_16, susceptibility_16, err_mag_16, err_susc_16 = [], [], [], [], []
with open('magnetization16', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_16.append(16*(float(row[0])-2.269)/2.269)
        magnetization_16.append(16*16*16**(-0.125)*float(row[1]))
        susceptibility_16.append(16*16*16**(-1.75)*float(row[2]))
        err_mag_16.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_16.append(16*16*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_16,energy_16, specific_heat_16, err_ene_16, err_sh_16 = [], [], [], [], []
with open('energy16', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_16.append(16*(float(row[0])-2.269)/2.269)
        energy_16.append(float(row[1]))
        specific_heat_16.append(16*16*float(row[2]))
        err_ene_16.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_16.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 32
T_32,magnetization_32, susceptibility_32, err_mag_32, err_susc_32 = [], [], [], [], []
with open('magnetization32', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_32.append(32*(float(row[0])-2.269)/2.269)
        magnetization_32.append(32*32*32**(-0.125)*float(row[1]))
        susceptibility_32.append(32*32*32**(-1.75)*float(row[2]))
        err_mag_32.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_32.append(32*32*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_32,energy_32, specific_heat_32, err_ene_32, err_sh_32 = [], [], [], [], []
with open('energy32', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_32.append(32*(float(row[0])-2.269)/2.269)
        energy_32.append(float(row[1]))
        specific_heat_32.append(32*32*float(row[2]))
        err_ene_32.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_32.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 64
T_64,magnetization_64, susceptibility_64, err_mag_64, err_susc_64 = [], [], [], [], []
with open('magnetization64', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_64.append(64*(float(row[0])-2.269)/2.269)
        magnetization_64.append(64*64*64**(-0.125)*float(row[1]))
        susceptibility_64.append(64*64*64**(-1.75)*float(row[2]))
        err_mag_64.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_64.append(64*64*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_64,energy_64, specific_heat_64, err_ene_64, err_sh_64 = [], [], [], [], []
with open('energy64', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_64.append(64*(float(row[0])-2.269)/2.269)
        energy_64.append(float(row[1]))
        specific_heat_64.append(64*64*float(row[2]))
        err_ene_64.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_64.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 128
T_128,magnetization_128, susceptibility_128, err_mag_128, err_susc_128 = [], [], [], [], []
with open('magnetization128', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_128.append(128*(float(row[0])-2.269)/2.269)
        magnetization_128.append(128*128*128**(-0.125)*float(row[1]))
        susceptibility_128.append(128*128*128**(-1.75)*float(row[2]))
        err_mag_128.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_128.append(128*128*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_128,energy_128, specific_heat_128, err_ene_128, err_sh_128 = [], [], [], [], []
with open('energy128', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_128.append(128*(float(row[0])-2.269)/2.269)
        energy_128.append(float(row[1]))
        specific_heat_128.append(128*128*float(row[2]))
        err_ene_128.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_128.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
        
# plot the energy and Magnetization
f = plt.figure(figsize=(18, 10), dpi=80, facecolor='w', edgecolor='k');    

plt.errorbar(T_8, energy_8,yerr= err_ene_8, fmt='.', label=' L=8');
plt.errorbar(T_16, energy_16,yerr= err_ene_16, fmt='.', label='L=16');
plt.errorbar(T_32, energy_32,yerr= err_ene_32,fmt='.', label='L=32');
plt.errorbar(T_64, energy_64,yerr= err_ene_64, fmt='.', label='L=64');
plt.errorbar(T_128, energy_128,yerr= err_ene_128, fmt='.', label='L=128');
plt.xlabel("t", fontsize=20);
plt.ylabel("Energy", fontsize=20);
plt.legend(loc = 'upper left')
#plt.savefig('energy.pdf')
plt.show()


plt.errorbar(T_8, magnetization_8, yerr=err_mag_8, label='L=8', fmt='.');
plt.errorbar(T_16, magnetization_16, yerr=err_mag_16, label='L=16', fmt='.');
plt.errorbar(T_32, magnetization_32, yerr=err_mag_32, label='L=32', fmt='.');
plt.errorbar(T_64, magnetization_64, yerr=err_mag_64, label='L=64', fmt='.');
plt.errorbar(T_128, magnetization_128, yerr=err_mag_128, label='L=128', fmt='.');
plt.xlabel("t", fontsize=20);
plt.ylabel("Magnetization", fontsize=20);
plt.legend()
#plt.savefig('magnetization.pdf')
plt.show()


#plt.errorbar(T_16, specific_heat_16, yerr = err_sh_16, fmt = '.', color="black", label='Specific Heat');
plt.plot(T_8, specific_heat_8, '.', label='L=8');
plt.plot(T_16, specific_heat_16, '.', label='L=16');
plt.plot(T_32, specific_heat_32, '.', label='L=32');
plt.plot(T_64, specific_heat_64,'.', label='L=64');
plt.plot(T_128, specific_heat_128, '.', label='L=128');
plt.xlabel("t", fontsize=20);
plt.ylabel("Specific Heat", fontsize=20);
plt.xlim(2,2.6)
plt.legend()
#plt.savefig('heatN.pdf')
plt.show()


plt.errorbar(T_8, susceptibility_8,  fmt='.', label='L=8');
plt.errorbar(T_16, susceptibility_16, fmt='.', label='L=16');
plt.errorbar(T_32, susceptibility_32,  fmt='.', label='L=32');
plt.errorbar(T_64, susceptibility_64,  fmt='.', label='L=64');
plt.errorbar(T_128, susceptibility_128,  fmt='.', label='L=128');
plt.xlabel("t", fontsize=20);
plt.ylabel("Susceptibility", fontsize=20);
plt.xlim(-5,25)
plt.legend()
#plt.savefig('susceptibilityN.pdf')
plt.show()

# %%
# %matplotlib inline
import csv
from __future__ import division
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt
import math

M = 5000

# L = 8
T_8,magnetization_8, susceptibility_8, err_mag_8, err_susc_8 = [], [], [], [], []
with open('magnetization8', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_8.append(8*(float(row[0])-2.269)/2.269)
        magnetization_8.append(8**(0.125)*float(row[1]))
        susceptibility_8.append(8*8*8**(-1.75)*float(row[2]))
        err_mag_8.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_8.append(8*8*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_8,energy_8, specific_heat_8, err_ene_8, err_sh_8 = [], [], [], [], []
with open('energy8', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_8.append(8*(float(row[0])-2.269)/2.269)
        energy_8.append(float(row[1]))
        specific_heat_8.append(8*8*float(row[2]))
        err_ene_8.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_8.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 16
T_16,magnetization_16, susceptibility_16, err_mag_16, err_susc_16 = [], [], [], [], []
with open('magnetization16', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_16.append(16*(float(row[0])-2.269)/2.269)
        magnetization_16.append(16**(0.125)*float(row[1]))
        susceptibility_16.append(16*16*16**(-1.75)*float(row[2]))
        err_mag_16.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_16.append(16*16*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_16,energy_16, specific_heat_16, err_ene_16, err_sh_16 = [], [], [], [], []
with open('energy16', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_16.append(16*(float(row[0])-2.269)/2.269)
        energy_16.append(float(row[1]))
        specific_heat_16.append(16*16*float(row[2]))
        err_ene_16.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_16.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 32
T_32,magnetization_32, susceptibility_32, err_mag_32, err_susc_32 = [], [], [], [], []
with open('magnetization32', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_32.append(32*(float(row[0])-2.269)/2.269)
        magnetization_32.append(32**(0.125)*float(row[1]))
        susceptibility_32.append(32*32*32**(-1.75)*float(row[2]))
        err_mag_32.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_32.append(32*32*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_32,energy_32, specific_heat_32, err_ene_32, err_sh_32 = [], [], [], [], []
with open('energy32', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_32.append(32*(float(row[0])-2.269)/2.269)
        energy_32.append(float(row[1]))
        specific_heat_32.append(32*32*float(row[2]))
        err_ene_32.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_32.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 64
T_64,magnetization_64, susceptibility_64, err_mag_64, err_susc_64 = [], [], [], [], []
with open('magnetization64', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_64.append(64*(float(row[0])-2.269)/2.269)
        magnetization_64.append(64**(0.125)*float(row[1]))
        susceptibility_64.append(64*64*64**(-1.75)*float(row[2]))
        err_mag_64.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_64.append(64*64*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_64,energy_64, specific_heat_64, err_ene_64, err_sh_64 = [], [], [], [], []
with open('energy64', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_64.append(64*(float(row[0])-2.269)/2.269)
        energy_64.append(float(row[1]))
        specific_heat_64.append(64*64*float(row[2]))
        err_ene_64.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_64.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
# L = 128
T_128,magnetization_128, susceptibility_128, err_mag_128, err_susc_128 = [], [], [], [], []
with open('magnetization128', 'r') as f:
    reader = csv.reader(f,delimiter=',')
    f.readline()
    for row in reader:
        T_128.append(128*(float(row[0])-2.269)/2.269)
        magnetization_128.append(128**(0.125)*float(row[1]))
        susceptibility_128.append(128*128*128**(-1.75)*float(row[2]))
        err_mag_128.append(math.sqrt(float(row[0])*float(row[2]))/math.sqrt(M))
        err_susc_128.append(128*128*float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/math.sqrt(M*float(row[0])))
T_128,energy_128, specific_heat_128, err_ene_128, err_sh_128 = [], [], [], [], []
with open('energy128', 'r') as g:
    reader = csv.reader(g,delimiter=',')
    g.readline()
    for row in reader:
        T_128.append(128*(float(row[0])-2.269)/2.269)
        energy_128.append(float(row[1]))
        specific_heat_128.append(128*128*float(row[2]))
        err_ene_128.append(math.sqrt((float(row[0])**2)*float(row[2]))/math.sqrt(M))
        err_sh_128.append(float(row[3])-2*float(row[1])*math.sqrt(float(row[2]))/(math.sqrt(M)*float(row[0])))
        
        
# plot the energy and Magnetization

plt.errorbar(T_8, magnetization_8, yerr=err_mag_8, label='L=8', fmt='.');
plt.errorbar(T_16, magnetization_16, yerr=err_mag_16, label='L=16', fmt='.');
plt.errorbar(T_32, magnetization_32, yerr=err_mag_32, label='L=32', fmt='.');
plt.errorbar(T_64, magnetization_64, yerr=err_mag_64, label='L=64', fmt='.');
plt.errorbar(T_128, magnetization_128, yerr=err_mag_128, label='L=128', fmt='.');
plt.xlabel("t", fontsize=20);
plt.ylabel(r"$ML^{ \beta }$", fontsize=20);
plt.legend()
#plt.xlim(0,25)
plt.savefig('magnetizationscaling.pdf')
plt.show()


plt.errorbar(T_8, susceptibility_8,  fmt='.', label='L=8');
plt.errorbar(T_16, susceptibility_16, fmt='.', label='L=16');
plt.errorbar(T_32, susceptibility_32,  fmt='.', label='L=32');
plt.errorbar(T_64, susceptibility_64,  fmt='.', label='L=64');
plt.errorbar(T_128, susceptibility_128,  fmt='.', label='L=128');
plt.xlabel("t", fontsize=20);
plt.ylabel(r"$ \chi L^{- \gamma }$" , fontsize=20);
plt.xlim(-5,25)
plt.legend()
plt.savefig('susceptibilityscaling.pdf')
plt.show()
